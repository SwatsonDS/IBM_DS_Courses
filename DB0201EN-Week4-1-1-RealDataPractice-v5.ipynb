# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Working with a real world data-set using SQL and Python
#
# Estaimted time needed: **30** minutes
#
# ## Objectives
#
# After complting this lab you will be able to:
#
# *   Understand the dataset for Chicago Public School level performance
# *   Store the dataset in an Db2 database on IBM Cloud instance
# *   Retrieve metadata about tables and columns and query data from mixed case columns
# *   Solve example problems to practice your SQL skills including using built-in database functions

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: [https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true](https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&download=true&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# **NOTE**:
#
# Do not download the dataset directly from City of Chicago portal. Instead download a static copy which is a more database friendly version from this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">link</a>.
#
# Now review some of its contents.

# %% [markdown]
# ### Store the dataset in a Table
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in the previous lab, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the CHICAGO PUBLIC SCHOOLS dataset and load the dataset into a new table called **SCHOOLS**.
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"><img src = "https://ibm.box.com/shared/static/uc4xjh1uxcc78ks1i18v668simioz4es.jpg"></a>

# %% [markdown]
# ### Connect to the database
#
# Let us now load the ipython-sql  extension and establish a connection with the database

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# Out:
# Requirement already satisfied: sqlalchemy==1.3.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.3.9)
# Requirement already satisfied: ibm_db_sa in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.3.3)
# Requirement already satisfied: sqlalchemy>=0.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ibm_db_sa) (1.3.9)

# %%
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# %sql ibm_db_sa://vdx86203:SbIf9aLjhFagJIu6@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb?security=SSL
# Out:
# 'Connected: vdx86203@bludb'

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the SCHOOLS table was created

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
# %sql SELECT TABSCHEMA,TABNAME,CREATE_TIME \
FROM syscat.tables \
WHERE TABSCHEMA = 'VDX86203'\
ORDER BY CREATE_TIME DESC;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('VDX86203', 'SCHOOLS', datetime.datetime(2021, 9, 23, 17, 49, 5, 960460)),
#  ('VDX86203', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2021, 9, 23, 14, 15, 32, 694193)),
#  ('VDX86203', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2021, 9, 22, 19, 55, 21, 844851)),
#  ('VDX86203', 'INSTRUCTOR', datetime.datetime(2021, 9, 22, 19, 18, 1, 575028)),
#  ('VDX86203', 'PETRESCUE', datetime.datetime(2021, 9, 22, 14, 2, 10, 543320)),
#  ('VDX86203', 'LOCATIONS', datetime.datetime(2021, 9, 21, 17, 45, 27, 598472)),
#  ('VDX86203', 'DEPARTMENTS', datetime.datetime(2021, 9, 21, 17, 45, 27, 372699)),
#  ('VDX86203', 'JOBS', datetime.datetime(2021, 9, 21, 17, 45, 27, 100776)),
#  ('VDX86203', 'JOB_HISTORY', datetime.datetime(2021, 9, 21, 17, 45, 26, 898689)),
#  ('VDX86203', 'EMPLOYEES', datetime.datetime(2021, 9, 21, 17, 45, 26, 616509)),
#  ('VDX86203', 'EXPLAIN_ACTUALS', datetime.datetime(2021, 9, 20, 20, 36, 51, 896078)),
#  ('VDX86203', 'ADVISE_TABLE', datetime.datetime(2021, 9, 20, 20, 36, 50, 217437)),
#  ('VDX86203', 'ADVISE_PARTITION', datetime.datetime(2021, 9, 20, 20, 36, 49, 863683)),
#  ('VDX86203', 'ADVISE_MQT', datetime.datetime(2021, 9, 20, 20, 36, 49, 591730)),
#  ('VDX86203', 'ADVISE_WORKLOAD', datetime.datetime(2021, 9, 20, 20, 36, 49, 304390)),
#  ('VDX86203', 'ADVISE_INDEX', datetime.datetime(2021, 9, 20, 20, 36, 49, 17219)),
#  ('VDX86203', 'ADVISE_INSTANCE', datetime.datetime(2021, 9, 20, 20, 36, 48, 776498)),
#  ('VDX86203', 'OBJECT_METRICS', datetime.datetime(2021, 9, 20, 20, 36, 48, 516657)),
#  ('VDX86203', 'EXPLAIN_DIAGNOSTIC_DATA', datetime.datetime(2021, 9, 20, 20, 36, 48, 223177)),
#  ('VDX86203', 'EXPLAIN_DIAGNOSTIC', datetime.datetime(2021, 9, 20, 20, 36, 47, 948451)),
#  ('VDX86203', 'EXPLAIN_STREAM', datetime.datetime(2021, 9, 20, 20, 36, 47, 671949)),
#  ('VDX86203', 'EXPLAIN_PREDICATE', datetime.datetime(2021, 9, 20, 20, 36, 47, 362508)),
#  ('VDX86203', 'EXPLAIN_OPERATOR', datetime.datetime(2021, 9, 20, 20, 36, 47, 75855)),
#  ('VDX86203', 'EXPLAIN_OBJECT', datetime.datetime(2021, 9, 20, 20, 36, 46, 936842)),
#  ('VDX86203', 'EXPLAIN_ARGUMENT', datetime.datetime(2021, 9, 20, 20, 36, 46, 640239)),
#  ('VDX86203', 'EXPLAIN_STATEMENT', datetime.datetime(2021, 9, 20, 20, 36, 46, 218038)),
#  ('VDX86203', 'EXPLAIN_INSTANCE', datetime.datetime(2021, 9, 20, 20, 36, 45, 910027)),
#  ('VDX86203', 'PETSALE', datetime.datetime(2021, 9, 20, 20, 20, 59, 822658))]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.TABLES contains the table metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES where TABSCHEMA='YOUR-DB2-USERNAME'
#
# or, you can retrieve list of all tables where the schema name is not one of the system created ones:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
#       where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
#
# or, just query for a specifc table that you want to verify exists in the database
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table
# %sql SELECT COUNT(*) FROM syscat.columns WHERE TABNAME = 'SCHOOLS';
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [(25850,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.COLUMNS contains the column metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# Now retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
# type in your query to retrieve all column names in the SCHOOLS table along with their datatypes and length
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'SCHOOLS';
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('10th Grade PLAN (2009)', 'CLOB    ', -1),
#  ('10th Grade PLAN (2009)', 'VARCHAR ', 3),
#  ('10th Grade PLAN (2009)', 'VARCHAR ', 4),
#  ('10th Grade PLAN (2009)', 'VARCHAR ', 5),
#  ('10th Grade PLAN (2010)', 'CLOB    ', -1),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 3),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 5),
#  ('10th_Grade_PLAN_(2009)', 'VARCHAR ', 4),
#  ('10th_Grade_PLAN_(2010)', 'VARCHAR ', 4),
#  ('10th_Grade_PLAN_2009', 'VARCHAR ', 4),
#  ('10th_Grade_PLAN_2010', 'VARCHAR ', 4),
#  ('10th_grade_plan_2009', 'VARCHAR ', 4),
#  ('10th_grade_plan_2010', 'VARCHAR ', 4),
#  ('11th Grade Average ACT (2011)', 'CLOB    ', -1),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 3),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 4),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 5),
#  ('11th_Grade_Average_ACT_(2011)', 'VARCHAR ', 4),
#  ('11th_Grade_Average_ACT_2011', 'VARCHAR ', 4),
#  ('11th_grade_average_act_2011', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2009)', 'CLOB    ', -1),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 3),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 5),
#  ('9th Grade EXPLORE (2010)', 'CLOB    ', -1),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 3),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 5),
#  ('9th_Grade_EXPLORE _2010', 'VARCHAR ', 4),
#  ('9th_Grade_EXPLORE_(2009)', 'VARCHAR ', 4),
#  ('9th_Grade_EXPLORE_(2010)', 'VARCHAR ', 4),
#  ('9th_Grade_EXPLORE_2009', 'VARCHAR ', 4),
#  ('9th_grade_explore_2009', 'VARCHAR ', 4),
#  ('9th_grade_explore_2010', 'VARCHAR ', 4),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE', 'VARCHAR ', 3),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 2),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 3),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 5),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'CLOB    ', -1),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'DECIMAL ', 4),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 5),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 6),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 10),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'DECIMAL ', 4),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 5),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 6),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 10),
#  ('Adequate_Yearly_Progress_Made_', 'CLOB    ', -1),
#  ('Average_Teacher_Attendance', 'CLOB    ', -1),
#  ('CITY', 'VARCHAR ', 5),
#  ('CITY', 'VARCHAR ', 7),
#  ('CITY', 'VARCHAR ', 20),
#  ('CITY', 'VARCHAR ', 100),
#  ('COL1', 'CHAR    ', 5),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 5),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 34),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 50),
#  ('COLLEGE_ELIGIBILITY', 'VARCHAR ', 4),
#  ('COLLEGE_ELIGIBILITY_RATE', 'VARCHAR ', 4),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 3),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 4),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 5),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('COLLEGE_ENROLLMENT', 'VARCHAR ', 5),
#  ('COLLEGE_ENROLLMENT', 'BIGINT  ', 8),
#  ('COLLEGE_ENROLLMENT_RATE', 'VARCHAR ', 4),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 3),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 4),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 5),
#  ('COLLEGE_ENROLLMENT__NUMBER_OF_STUDENTS_', 'SMALLINT', 2),
#  ('COLLEGE_ENROLLMENT__NUMBER_OF_STUDENTS_', 'DECIMAL ', 7),
#  ('COLUMN_0', 'INTEGER ', 4),
#  ('COLUMN_1', 'VARCHAR ', 64),
#  ('COLUMN_10', 'VARCHAR ', 34),
#  ('COLUMN_11', 'VARCHAR ', 3),
#  ('COLUMN_12', 'VARCHAR ', 8),
#  ('COLUMN_12', 'VARCHAR ', 12),
#  ('COLUMN_13', 'VARCHAR ', 16),
#  ('COLUMN_14', 'VARCHAR ', 15),
#  ('COLUMN_15', 'VARCHAR ', 3),
#  ('COLUMN_16', 'VARCHAR ', 11),
#  ('COLUMN_17', 'SMALLINT', 2),
#  ('COLUMN_18', 'VARCHAR ', 11),
#  ('COLUMN_19', 'VARCHAR ', 3),
#  ('COLUMN_2', 'VARCHAR ', 2),
#  ('COLUMN_20', 'VARCHAR ', 11),
#  ('COLUMN_21', 'SMALLINT', 2),
#  ('COLUMN_22', 'VARCHAR ', 11),
#  ('COLUMN_23', 'SMALLINT', 2),
#  ('COLUMN_24', 'VARCHAR ', 4),
#  ('COLUMN_24', 'VARCHAR ', 11),
#  ('COLUMN_25', 'VARCHAR ', 3),
#  ('COLUMN_26', 'VARCHAR ', 11),
#  ('COLUMN_27', 'VARCHAR ', 3),
#  ('COLUMN_28', 'VARCHAR ', 7),
#  ('COLUMN_29', 'VARCHAR ', 3),
#  ('COLUMN_3', 'VARCHAR ', 29),
#  ('COLUMN_3', 'VARCHAR ', 30),
#  ('COLUMN_30', 'VARCHAR ', 7),
#  ('COLUMN_31', 'VARCHAR ', 3),
#  ('COLUMN_32', 'DECIMAL ', 4),
#  ('COLUMN_32', 'VARCHAR ', 6),
#  ('COLUMN_33', 'DECIMAL ', 5),
#  ('COLUMN_34', 'DECIMAL ', 4),
#  ('COLUMN_34', 'VARCHAR ', 6),
#  ('COLUMN_35', 'DECIMAL ', 5),
#  ('COLUMN_35', 'VARCHAR ', 7),
#  ('COLUMN_36', 'VARCHAR ', 4),
#  ('COLUMN_37', 'VARCHAR ', 4),
#  ('COLUMN_38', 'VARCHAR ', 4),
#  ('COLUMN_39', 'VARCHAR ', 4),
#  ('COLUMN_4', 'VARCHAR ', 7),
#  ('COLUMN_40', 'VARCHAR ', 4),
#  ('COLUMN_41', 'VARCHAR ', 4),
#  ('COLUMN_42', 'VARCHAR ', 4),
#  ('COLUMN_43', 'VARCHAR ', 4),
#  ('COLUMN_44', 'VARCHAR ', 4),
#  ('COLUMN_45', 'VARCHAR ', 4),
#  ('COLUMN_46', 'VARCHAR ', 4),
#  ('COLUMN_47', 'VARCHAR ', 4),
#  ('COLUMN_48', 'DECIMAL ', 4),
#  ('COLUMN_49', 'DECIMAL ', 4),
#  ('COLUMN_5', 'VARCHAR ', 2),
#  ('COLUMN_50', 'DECIMAL ', 3),
#  ('COLUMN_51', 'DECIMAL ', 3),
#  ('COLUMN_52', 'VARCHAR ', 6),
#  ('COLUMN_53', 'VARCHAR ', 6),
#  ('COLUMN_54', 'VARCHAR ', 4),
#  ('COLUMN_55', 'VARCHAR ', 4),
#  ('COLUMN_56', 'VARCHAR ', 4),
#  ('COLUMN_57', 'VARCHAR ', 4),
#  ('COLUMN_58', 'VARCHAR ', 4),
#  ('COLUMN_59', 'VARCHAR ', 4),
#  ('COLUMN_6', 'INTEGER ', 4),
#  ('COLUMN_60', 'VARCHAR ', 3),
#  ('COLUMN_61', 'VARCHAR ', 4),
#  ('COLUMN_62', 'VARCHAR ', 3),
#  ('COLUMN_63', 'VARCHAR ', 4),
#  ('COLUMN_64', 'VARCHAR ', 4),
#  ('COLUMN_65', 'VARCHAR ', 4),
#  ('COLUMN_66', 'SMALLINT', 2),
#  ('COLUMN_67', 'SMALLINT', 2),
#  ('COLUMN_68', 'VARCHAR ', 4),
#  ('COLUMN_69', 'BIGINT  ', 8),
#  ('COLUMN_69', 'DECIMAL ', 13),
#  ('COLUMN_7', 'VARCHAR ', 14),
#  ('COLUMN_70', 'DECIMAL ', 13),
#  ('COLUMN_71', 'DECIMAL ', 13),
#  ('COLUMN_71', 'DECIMAL ', 18),
#  ('COLUMN_72', 'DECIMAL ', 18),
#  ('COLUMN_73', 'SMALLINT', 2),
#  ('COLUMN_73', 'DECIMAL ', 18),
#  ('COLUMN_74', 'SMALLINT', 2),
#  ('COLUMN_74', 'VARCHAR ', 22),
#  ('COLUMN_75', 'SMALLINT', 2),
#  ('COLUMN_75', 'VARCHAR ', 22),
#  ('COLUMN_76', 'SMALLINT', 2),
#  ('COLUMN_77', 'SMALLINT', 2),
#  ('COLUMN_77', 'VARCHAR ', 27),
#  ('COLUMN_78', 'VARCHAR ', 27),
#  ('COLUMN_8', 'VARCHAR ', 78),
#  ('COLUMN_9', 'VARCHAR ', 40),
#  ('COMMUNITY_AREA_NAME', 'CLOB    ', -1),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 5),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 12),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('COMMUNITY_AREA_NUMBER', 'VARCHAR ', 5),
#  ('COMMUNITY_AREA_NUMBER', 'BIGINT  ', 8),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 5),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 7),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 15),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 25),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 50),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 5),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 16),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 20),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 25),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 50),
#  ('CPS_Performance_Policy_Level', 'CLOB    ', -1),
#  ('CPS_Performance_Policy_Status', 'CLOB    ', -1),
#  ('City', 'CLOB    ', -1),
#  ('Collaborative_Name', 'CLOB    ', -1),
#  ('College_Eligibility__', 'CLOB    ', -1),
#  ('College_Enrollment_Rate__', 'CLOB    ', -1),
#  ('DEGREE', 'VARCHAR ', 2),
#  ('ELEMENTARY', 'VARCHAR ', 2),
#  ('ELEMENTARY_MIDDLE_HIGH_SCHOOL', 'VARCHAR ', 2),
#  ('ELEMENTARY_MIDDLE_OR_HIGH_SCHOOL', 'VARCHAR ', 2),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 5),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 6),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 11),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 20),
#  ('ENVIRONMENT_RATING', 'VARCHAR ', 11),
#  ('ENVIRONMENT_SCORE', 'SMALLINT', 2),
#  ('ENVIRONMENT_SCORE', 'DECIMAL ', 4),
#  ('ENVIRONMENT_SCORE', 'VARCHAR ', 5),
#  ('Elementary, Middle, or High School', 'CLOB    ', -1),
#  ('Elementary, Middle, or High School', 'VARCHAR ', 2),
#  ('Elementary, Middle, or High School', 'VARCHAR ', 7),
#  ('Elementary,Middle,orHighSchool', 'VARCHAR ', 2),
#  ('Elementary_Middle_High School', 'VARCHAR ', 2),
#  ('Elementary_Middle_or_High School', 'VARCHAR ', 2),
#  ('Environment_Icon', 'CLOB    ', -1),
#  ('Environment_Score', 'DOUBLE  ', 8),
#  ('FAMILY_INVOLVEMENT_ICON', 'VARCHAR ', 5),
#  ('FAMILY_INVOLVEMENT_ICON', 'VARCHAR ', 11),
#  ('FAMILY_INVOLVEMENT_ICON', 'VARCHAR ', 20),
#  ('FAMILY_INVOLVEMENT_SCORE', 'SMALLINT', 2),
#  ('FAMILY_INVOLVEMENT_SCORE', 'VARCHAR ', 3),
#  ('FAMILY_INVOLVEMENT_SCORE', 'VARCHAR ', 5),
#  ('FAMILY_RATING', 'VARCHAR ', 11),
#  ('FRESHMAN_ON_TRACK_RATE', 'VARCHAR ', 4),
#  ('FRESHMAN_ON_TRACK_RATE__', 'VARCHAR ', 3),
#  ('FRESHMAN_ON_TRACK_RATE__', 'VARCHAR ', 4),
#  ('FRESHMAN_ON_TRACK_RATE__', 'VARCHAR ', 5),
#  ('Family_Involvement_Icon', 'CLOB    ', -1),
#  ('Family_Involvement_Score', 'CLOB    ', -1),
#  ('Freshman_on_Track_Rate__', 'CLOB    ', -1),
#  ('GENERAL_SERVICES_ROUTE', 'SMALLINT', 2),
#  ('GENERAL_SERVICES_ROUTE', 'VARCHAR ', 5),
#  ('GR10_PLAN_2009', 'VARCHAR ', 4),
#  ('GR10_PLAN_2010', 'VARCHAR ', 4),
#  ('GR11_AVERAGE_ACT_2011', 'VARCHAR ', 4),
#  ('GR3_5_GRADE_LEVEL_MATH', 'VARCHAR ', 4),
#  ('GR3_5_GRADE_LEVEL_MATH__', 'DECIMAL ', 4),
#  ('GR3_5_GRADE_LEVEL_MATH__', 'VARCHAR ', 4),
#  ('GR3_5_GRADE_LEVEL_MATH__', 'VARCHAR ', 5),
#  ('GR3_5_GRADE_LEVEL_READ', 'VARCHAR ', 4),
#  ('GR3_5_GRADE_LEVEL_READ__', 'DECIMAL ', 4),
#  ('GR3_5_GRADE_LEVEL_READ__', 'VARCHAR ', 4),
#  ('GR3_5_GRADE_LEVEL_READ__', 'VARCHAR ', 5),
#  ('GR3_5_KEEP_PACE_MATH', 'VARCHAR ', 4),
#  ('GR3_5_KEEP_PACE_MATH__', 'DECIMAL ', 4),
#  ('GR3_5_KEEP_PACE_MATH__', 'VARCHAR ', 4),
#  ('GR3_5_KEEP_PACE_MATH__', 'VARCHAR ', 5),
#  ('GR3_5_KEEP_PACE_READ', 'VARCHAR ', 4),
#  ('GR3_5_KEEP_PACE_READ__', 'DECIMAL ', 4),
#  ('GR3_5_KEEP_PACE_READ__', 'VARCHAR ', 4),
#  ('GR3_5_KEEP_PACE_READ__', 'VARCHAR ', 5),
#  ('GR6_8_GRADE_LEVEL_MATH', 'VARCHAR ', 4),
#  ('GR6_8_GRADE_LEVEL_MATH__', 'DECIMAL ', 4),
#  ('GR6_8_GRADE_LEVEL_MATH__', 'VARCHAR ', 4),
#  ('GR6_8_GRADE_LEVEL_MATH__', 'VARCHAR ', 5),
#  ('GR6_8_GRADE_LEVEL_READ', 'VARCHAR ', 4),
#  ('GR6_8_GRADE_LEVEL_READ__', 'DECIMAL ', 4),
#  ('GR6_8_GRADE_LEVEL_READ__', 'VARCHAR ', 4),
#  ('GR6_8_GRADE_LEVEL_READ__', 'VARCHAR ', 5),
#  ('GR6_8_KEEP_PACE_MATH', 'VARCHAR ', 4),
#  ('GR6_8_KEEP_PACE_MATH_', 'SMALLINT', 2),
#  ('GR6_8_KEEP_PACE_MATH_', 'VARCHAR ', 4),
#  ('GR6_8_KEEP_PACE_MATH_', 'VARCHAR ', 5),
#  ('GR6_8_KEEP_PACE_READ', 'VARCHAR ', 4),
#  ('GR6_8_KEEP_PACE_READ__', 'DECIMAL ', 4),
#  ('GR6_8_KEEP_PACE_READ__', 'VARCHAR ', 4),
#  ('GR6_8_KEEP_PACE_READ__', 'VARCHAR ', 5),
#  ('GR9_EXPLORE_2009', 'VARCHAR ', 4),
#  ('GR9_EXPLORE_2010', 'VARCHAR ', 4),
#  ('GRADUATION_RATE', 'VARCHAR ', 4),
#  ('GRADUATION_RATE__', 'VARCHAR ', 3),
#  ('GRADUATION_RATE__', 'VARCHAR ', 4),
#  ('GRADUATION_RATE__', 'VARCHAR ', 5),
#  ('GR_8_EXPLORE_MATH', 'VARCHAR ', 4),
#  ('GR_8_EXPLORE_MATH__', 'DECIMAL ', 4),
#  ('GR_8_EXPLORE_MATH__', 'VARCHAR ', 4),
#  ('GR_8_EXPLORE_MATH__', 'VARCHAR ', 5),
#  ('GR_8_EXPLORE_READ', 'VARCHAR ', 4),
#  ('GR_8_EXPLORE_READ__', 'DECIMAL ', 4),
#  ('GR_8_EXPLORE_READ__', 'VARCHAR ', 4),
#  ('GR_8_EXPLORE_READ__', 'VARCHAR ', 5),
#  ('General_Services_Route', 'BIGINT  ', 8),
#  ('Gr3_5_Grade_Level_Math__', 'CLOB    ', -1),
#  ('Gr3_5_Grade_Level_Read__', 'CLOB    ', -1),
#  ('Gr3_5_Keep_Pace_Math__', 'CLOB    ', -1),
#  ('Gr3_5_Keep_Pace_Read__', 'CLOB    ', -1),
#  ('Gr6_8_Grade_Level_Math__', 'CLOB    ', -1),
#  ('Gr6_8_Grade_Level_Read__', 'CLOB    ', -1),
#  ('Gr6_8_Keep_Pace_Math_', 'CLOB    ', -1),
#  ('Gr6_8_Keep_Pace_Read__', 'CLOB    ', -1),
#  ('Gr_8_Explore_Math__', 'CLOB    ', -1),
#  ('Gr_8_Explore_Read__', 'CLOB    ', -1),
#  ('Graduation_Rate__', 'CLOB    ', -1),
#  ('HEALTHY_SCHOOLS_CERTIFIED_', 'VARCHAR ', 3),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'CLOB    ', -1),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR ', 3),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR ', 5),
#  ('ID', 'INTEGER ', 4),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'DECIMAL ', 5),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'VARCHAR ', 5),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'VARCHAR ', 6),
#  ('INDIVIDUALIZED_EDUCATION_PROGRAM_COMPLIANCE_RATE', 'VARCHAR ', 7),
#  ('INSTRUCTION_ICON', 'VARCHAR ', 5),
#  ('INSTRUCTION_ICON', 'VARCHAR ', 6),
#  ('INSTRUCTION_ICON', 'VARCHAR ', 11),
#  ('INSTRUCTION_ICON', 'VARCHAR ', 20),
#  ('INSTRUCTION_RATING', 'VARCHAR ', 11),
#  ('INSTRUCTION_SCORE', 'SMALLINT', 2),
#  ('INSTRUCTION_SCORE', 'DECIMAL ', 4),
#  ('INSTRUCTION_SCORE', 'VARCHAR ', 5),
#  ('ISAT_EXCEEDING_MATH', 'DECIMAL ', 4),
#  ('ISAT_EXCEEDING_MATH_', 'DECIMAL ', 4),
#  ('ISAT_EXCEEDING_MATH__', 'DECIMAL ', 4),
#  ('ISAT_EXCEEDING_MATH__', 'VARCHAR ', 5),
#  ('ISAT_EXCEEDING_MATH__', 'DECIMAL ', 10),
#  ('ISAT_EXCEEDING_READING', 'DECIMAL ', 4),
#  ('ISAT_EXCEEDING_READING__', 'DECIMAL ', 4),
#  ('ISAT_EXCEEDING_READING__', 'VARCHAR ', 5),
#  ('ISAT_EXCEEDING_READING__', 'DECIMAL ', 10),
#  ('ISAT_Exceeding_Math__', 'DOUBLE  ', 8),
#  ('ISAT_Exceeding_Reading__', 'DOUBLE  ', 8),
#  ('ISAT_VALUE_ADD_COLOR_MATH', 'VARCHAR ', 5),
#  ('ISAT_VALUE_ADD_COLOR_MATH', 'VARCHAR ', 6),
#  ('ISAT_VALUE_ADD_COLOR_MATH', 'VARCHAR ', 10),
#  ('ISAT_VALUE_ADD_COLOR_READ', 'VARCHAR ', 5),
#  ('ISAT_VALUE_ADD_COLOR_READ', 'VARCHAR ', 6),
#  ('ISAT_VALUE_ADD_COLOR_READ', 'VARCHAR ', 10),
#  ('ISAT_VALUE_ADD_MATH', 'DECIMAL ', 2),
#  ('ISAT_VALUE_ADD_MATH', 'DECIMAL ', 3),
#  ('ISAT_VALUE_ADD_MATH', 'VARCHAR ', 5),
#  ('ISAT_VALUE_ADD_MATH', 'DECIMAL ', 10),
#  ('ISAT_VALUE_ADD_READ', 'DECIMAL ', 2),
#  ('ISAT_VALUE_ADD_READ', 'DECIMAL ', 3),
#  ('ISAT_VALUE_ADD_READ', 'VARCHAR ', 5),
#  ('ISAT_VALUE_ADD_READ', 'DECIMAL ', 10),
#  ('ISAT_Value_Add_Color_Math', 'CLOB    ', -1),
#  ('ISAT_Value_Add_Color_Read', 'CLOB    ', -1),
#  ('ISAT_Value_Add_Math', 'DOUBLE  ', 8),
#  ('ISAT_Value_Add_Read', 'DOUBLE  ', 8),
#  ('Individualized_Education_Program_Compliance_Rate', 'CLOB    ', -1),
#  ('Instruction_Icon', 'CLOB    ', -1),
#  ('Instruction_Score', 'DOUBLE  ', 8),
#  ('LATITUDE', 'VARCHAR ', 5),
#  ('LATITUDE', 'DECIMAL ', 18),
#  ('LEADERS_ICON', 'VARCHAR ', 4),
#  ('LEADERS_ICON', 'VARCHAR ', 5),
#  ('LEADERS_ICON', 'VARCHAR ', 6),
#  ('LEADERS_ICON', 'VARCHAR ', 10),
#  ('LEADERS_ICON', 'VARCHAR ', 11),
#  ('LEADERS_RATING', 'VARCHAR ', 4),
#  ('LEADERS_SCORE', 'SMALLINT', 2),
#  ('LEADERS_SCORE', 'VARCHAR ', 3),
#  ('LEADERS_SCORE', 'VARCHAR ', 5),
#  ('LINK', 'VARCHAR ', 5),
#  ('LINK', 'VARCHAR ', 78),
#  ('LINK', 'VARCHAR ', 100),
#  ('LINK', 'VARCHAR ', 1000),
#  ('LOCATION', 'VARCHAR ', 5),
#  ('LOCATION', 'VARCHAR ', 27),
#  ('LOCATION', 'VARCHAR ', 48),
#  ('LOCATION', 'VARCHAR ', 50),
#  ('LONGITUDE', 'VARCHAR ', 5),
#  ('LONGITUDE', 'DECIMAL ', 18),
#  ('Latitude', 'DOUBLE  ', 8),
#  ('Leaders_Icon', 'CLOB    ', -1),
#  ('Leaders_Score', 'CLOB    ', -1),
#  ('Link', 'CLOB    ', -1),
#  ('Location', 'CLOB    ', -1),
#  ('Longitude', 'DOUBLE  ', 8),
#  ('NAME_OF_SCHOOL', 'CLOB    ', -1),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 5),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 33),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 64),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 68),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 100),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 128),
#  ('NAME_OF_SCHOOL', 'VARCHAR ', 255),
#  ('NETWORK_MANAGER', 'VARCHAR ', 5),
#  ('NETWORK_MANAGER', 'VARCHAR ', 28),
#  ('NETWORK_MANAGER', 'VARCHAR ', 40),
#  ('NETWORK_MANAGER', 'VARCHAR ', 50),
#  ('NET_CHANGE_EXPLORE_AND_PLAN', 'VARCHAR ', 3),
#  ('NET_CHANGE_EXPLORE_AND_PLAN', 'VARCHAR ', 4),
#  ('NET_CHANGE_EXPLORE_AND_PLAN', 'VARCHAR ', 5),
#  ('NET_CHANGE_PLAN_AND_ACT', 'VARCHAR ', 3),
#  ('NET_CHANGE_PLAN_AND_ACT', 'VARCHAR ', 4),
#  ('NET_CHANGE_PLAN_AND_ACT', 'VARCHAR ', 5),
#  ('Net_Change_EXPLORE_and_PLAN', 'CLOB    ', -1),
#  ('Net_Change_PLAN_and_ACT', 'CLOB    ', -1),
#  ('Network_Manager', 'CLOB    ', -1),
#  ('PARENT_ENGAGEMENT_ICON', 'VARCHAR ', 5),
#  ('PARENT_ENGAGEMENT_ICON', 'VARCHAR ', 6),
#  ('PARENT_ENGAGEMENT_ICON', 'VARCHAR ', 7),
#  ('PARENT_ENGAGEMENT_SCORE', 'SMALLINT', 2),
#  ('PARENT_ENGAGEMENT_SCORE', 'VARCHAR ', 3),
#  ('PARENT_ENGAGEMENT_SCORE', 'VARCHAR ', 5),
#  ('PARENT_ENVIRONMENT_ICON', 'VARCHAR ', 5),
#  ('PARENT_ENVIRONMENT_ICON', 'VARCHAR ', 7),
#  ('PARENT_ENVIRONMENT_ICON', 'VARCHAR ', 15),
#  ('PARENT_ENVIRONMENT_SCORE', 'SMALLINT', 2),
#  ('PARENT_ENVIRONMENT_SCORE', 'VARCHAR ', 3),
#  ('PARENT_ENVIRONMENT_SCORE', 'VARCHAR ', 5),
#  ('PHONE_NUMBER', 'VARCHAR ', 5),
#  ('PHONE_NUMBER', 'VARCHAR ', 14),
#  ('PK_2_LITERACY', 'VARCHAR ', 4),
#  ('PK_2_LITERACY__', 'DECIMAL ', 4),
#  ('PK_2_LITERACY__', 'VARCHAR ', 4),
#  ('PK_2_LITERACY__', 'VARCHAR ', 5),
#  ('PK_2_MATH', 'VARCHAR ', 4),
#  ('PK_2_MATH__', 'DECIMAL ', 4),
#  ('PK_2_MATH__', 'VARCHAR ', 4),
#  ('PK_2_MATH__', 'VARCHAR ', 5),
#  ('POLICE_DISTRICT', 'SMALLINT', 2),
#  ('POLICE_DISTRICT', 'VARCHAR ', 5),
#  ('Parent_Engagement_Icon', 'CLOB    ', -1),
#  ('Parent_Engagement_Score', 'CLOB    ', -1),
#  ('Parent_Environment_Icon', 'CLOB    ', -1),
#  ('Parent_Environment_Score', 'CLOB    ', -1),
#  ('Phone_Number', 'CLOB    ', -1),
#  ('Pk_2_Literacy__', 'CLOB    ', -1),
#  ('Pk_2_Math__', 'CLOB    ', -1),
#  ('Police_District', 'BIGINT  ', 8),
#  ('RATE_OF_MISCONDUCTS_PER_100_STUDENTS', 'DECIMAL ', 5),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS', 'DECIMAL ', 5),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 'SMALLINT', 2),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 'DECIMAL ', 5),
#  ('RATE_OF_MISCONDUCTS__PER_100_STUDENTS_', 'VARCHAR ', 5),
#  ('RCDTS_CODE', 'BIGINT  ', 8),
#  ('Rate_of_Misconducts__per_100_students_', 'DOUBLE  ', 8),
#  ('SAFETY_ICON', 'VARCHAR ', 5),
#  ('SAFETY_ICON', 'VARCHAR ', 11),
#  ('SAFETY_ICON', 'VARCHAR ', 20),
#  ('SAFETY_ICON', 'VARCHAR ', 50),
#  ('SAFETY_RATING', 'VARCHAR ', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('SAFETY_SCORE', 'DECIMAL ', 4),
#  ('SAFETY_SCORE', 'VARCHAR ', 5),
#  ('SAFETY_SCORE', 'DOUBLE  ', 8),
#  ('SCHOOLS_TYPE', 'VARCHAR ', 2),
#  ('SCHOOL_ID', 'INTEGER ', 4),
#  ('SCHOOL_ID', 'VARCHAR ', 666),
#  ('SCHOOL_NAME', 'VARCHAR ', 64),
#  ('SCHOOL_NAME', 'VARCHAR ', 65),
#  ('SCHOOL_TYPE', 'VARCHAR ', 2),
#  ('SCHOOL_TYPE', 'VARCHAR ', 3),
#  ('STATE', 'VARCHAR ', 2),
#  ('STATE', 'VARCHAR ', 5),
#  ('STREET_ADDRESS', 'VARCHAR ', 5),
#  ('STREET_ADDRESS', 'VARCHAR ', 16),
#  ('STREET_ADDRESS', 'VARCHAR ', 29),
#  ('STREET_ADDRESS', 'VARCHAR ', 30),
#  ('STREET_ADDRESS', 'VARCHAR ', 100),
#  ('STREET_ADDRESS', 'VARCHAR ', 255),
#  ('STUDENTS_PASSING_ALGEBRA', 'VARCHAR ', 4),
#  ('STUDENTS_PASSING__ALGEBRA', 'VARCHAR ', 4),
#  ('STUDENTS_PASSING__ALGEBRA__', 'DECIMAL ', 4),
#  ('STUDENTS_PASSING__ALGEBRA__', 'VARCHAR ', 4),
#  ('STUDENTS_PASSING__ALGEBRA__', 'VARCHAR ', 5),
#  ('STUDENTS_TAKING_ALGEBRA', 'VARCHAR ', 4),
#  ('STUDENTS_TAKING__ALGEBRA__', 'DECIMAL ', 4),
#  ('STUDENTS_TAKING__ALGEBRA__', 'VARCHAR ', 4),
#  ('STUDENTS_TAKING__ALGEBRA__', 'VARCHAR ', 5),
#  ('STUDENTS_TAKING__ALGEBRA__', 'VARCHAR ', 10),
#  ('Safety_Icon', 'CLOB    ', -1),
#  ('School_ID', 'BIGINT  ', 8),
#  ('State', 'CLOB    ', -1),
#  ('Street_Address', 'CLOB    ', -1),
#  ('Students_Passing__Algebra__', 'CLOB    ', -1),
#  ('Students_Taking__Algebra__', 'CLOB    ', -1),
#  ('TEACHERS_ICON', 'VARCHAR ', 5),
#  ('TEACHERS_ICON', 'VARCHAR ', 6),
#  ('TEACHERS_ICON', 'VARCHAR ', 11),
#  ('TEACHERS_ICON', 'VARCHAR ', 20),
#  ('TEACHERS_RATING', 'VARCHAR ', 11),
#  ('TEACHERS_SCORE', 'SMALLINT', 2),
#  ('TEACHERS_SCORE', 'VARCHAR ', 3),
#  ('TEACHERS_SCORE', 'VARCHAR ', 5),
#  ('TRACK_SCHEDULE', 'VARCHAR ', 5),
#  ('TRACK_SCHEDULE', 'VARCHAR ', 8),
#  ('TRACK_SCHEDULE', 'VARCHAR ', 12),
#  ('TRACK_SCHEDULE', 'VARCHAR ', 20),
#  ('TRACK_SCHEDULE', 'VARCHAR ', 50),
#  ('TYPE', 'VARCHAR ', 2),
#  ('TYPE_SCHOOL', 'VARCHAR ', 2),
#  ('Teachers_Icon', 'CLOB    ', -1),
#  ('Teachers_Score', 'CLOB    ', -1),
#  ('Track_Schedule', 'CLOB    ', -1),
#  ('WARD', 'SMALLINT', 2),
#  ('WARD', 'VARCHAR ', 5),
#  ('Ward', 'BIGINT  ', 8),
#  ('X_COORDINATE', 'VARCHAR ', 5),
#  ('X_COORDINATE', 'DOUBLE  ', 8),
#  ('X_COORDINATE', 'DECIMAL ', 13),
#  ('X_COORDINATE', 'DECIMAL ', 27),
#  ('Y_COORDINATE', 'VARCHAR ', 5),
#  ('Y_COORDINATE', 'DOUBLE  ', 8),
#  ('Y_COORDINATE', 'DECIMAL ', 13),
#  ('Y_COORDINATE', 'DECIMAL ', 27),
#  ('ZIP_CODE', 'INTEGER ', 4),
#  ('ZIP_CODE', 'VARCHAR ', 5),
#  ('ZIP_Code', 'BIGINT  ', 8),
#  ('city', 'VARCHAR ', 18),
#  ('country', 'VARCHAR ', 3),
#  ('index', 'BIGINT  ', 8),
#  ('name_full', 'VARCHAR ', 69),
#  ('schoolID', 'VARCHAR ', 13),
#  ('school_type', 'VARCHAR ', 2),
#  ('state', 'VARCHAR ', 2)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# or
#
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'SCHOOLS'
#
# -->

# %%
### Questions

1.  Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
2.  What is the name of "Community Area Name" column in your table? Does it have spaces?
3.  Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "\_"?

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %%
# %sql SELECT COUNT(SCHOOL_TYPE) FROM SCHOOLS WHERE SCHOOL_TYPE = 'ES';
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [(462,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Which column specifies the school type e.g. 'ES', 'MS', 'HS'? ("Elementary School, Middle School, High School")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Does the column name have mixed case, spaces or other special characters?
# If so, ensure you use double quotes around the "Name of the Column"
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SCHOOLS where school_type = 'ES'
#
# Correct answer: 462
#
# -->

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %%
# %sql SELECT MAX(SAFETY_SCORE) FROM SCHOOLS;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [(99,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the MAX() function
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from SCHOOLS
#
# Correct answer: 99
# -->

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %%
# %sql SELECT NAME_OF_SCHOOL,SAFETY_SCORE FROM SCHOOLS WHERE SAFETY_SCORE = (SELECT MAX(SAFETY_SCORE) FROM SCHOOLS);
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('Abraham Lincoln Elementary School', 99),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('Augustus H Burley Elementary School', 99),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('Ellen Mitchell Elementary School', 99),
#  ('James E McDade Elementary Classical School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('LaSalle Elementary Language Academy', 99),
#  ('Mary E Courtenay Elementary Language Arts Center', 99),
#  ('Northside College Preparatory High School', 99),
#  ('Northside Learning Center High School', 99),
#  ('Norwood Park Elementary School', 99),
#  ('Oriole Park Elementary School', 99),
#  ('Sauganash Elementary School', 99),
#  ('Stephen Decatur Classical Elementary School', 99),
#  ('Talman Elementary School', 99),
#  ('Wildwood Elementary School', 99)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# In the previous problem we found out that the highest Safety Score is 99, so we can use that as an input in the where clause:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where Safety_Score = 99
#
# or, a better way:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where \
#   Safety_Score= (select MAX(Safety_Score) from SCHOOLS)
#
#
# Correct answer: several schools with with Safety Score of 99.
# -->

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %sql SELECT NAME_OF_SCHOOL,AVERAGE_STUDENT_ATTENDANCE FROM SCHOOLS\
ORDER BY AVERAGE_STUDENT_ATTENDANCE DESC NULLS LAST\
LIMIT 10;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
#     order by Average_Student_Attendance desc nulls last limit 10
#
# -->

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %sql SELECT NAME_OF_SCHOOL,AVERAGE_STUDENT_ATTENDANCE FROM SCHOOLS\
ORDER BY AVERAGE_STUDENT_ATTENDANCE NULLS LAST\
LIMIT 5;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %sql SELECT NAME_OF_SCHOOL,REPLACE(AVERAGE_STUDENT_ATTENDANCE,'%','') FROM SCHOOLS\
ORDER BY AVERAGE_STUDENT_ATTENDANCE NULLS LAST\
LIMIT 5;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the REPLACE() function to replace '%' with ''
# See documentation for this function at:
# https://www.ibm.com/support/knowledgecenter/en/SSEPGG_10.5.0/com.ibm.db2.luw.sql.ref.doc/doc/r0000843.html
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql SELECT Name_of_School, REPLACE(Average_Student_Attendance, '%', '') \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %%
# %sql SELECT NAME_OF_SCHOOL,REPLACE(AVERAGE_STUDENT_ATTENDANCE,'%','') FROM SCHOOLS\
WHERE AVERAGE_STUDENT_ATTENDANCE < '70%';
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Chicago Vocational Career Academy High School', '68.80'),
#  ('Dyett High School', '62.50'),
#  ('Manley Career Academy High School', '66.80'),
#  ('Orr Academy High School', '66.30'),
#  ('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Roberto Clemente Community Academy High School', '69.60'),
#  ('Wendell Phillips Academy High School', '63.00')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# The datatype of the "Average_Student_Attendance" column is varchar.
# So you cannot use it as is in the where clause for a numeric comparison.
# First use the CAST() function to cast it as a DECIMAL or DOUBLE
# e.g. CAST("Column_Name" as DOUBLE)
# or simply: DECIMAL("Column_Name")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget the '%' age sign needs to be removed before casting
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
#      order by Average_Student_Attendance
#
# or,
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      where DECIMAL ( REPLACE(Average_Student_Attendance, '%', '') ) < 70 \
#      order by Average_Student_Attendance
#
# -->

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %%
# %sql SELECT DISTINCT(COMMUNITY_AREA_NUMBER),SUM(COLLEGE_ENROLLMENT) AS SUM_COLL_ENROLL FROM SCHOOLS\
GROUP BY COMMUNITY_AREA_NUMBER;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [(1, 4068),
#  (2, 8197),
#  (3, 4388),
#  (4, 4132),
#  (5, 7541),
#  (6, 7055),
#  (7, 5615),
#  (8, 3362),
#  (9, 910),
#  (10, 6469),
#  (11, 1755),
#  (12, 1431),
#  (13, 4210),
#  (14, 6864),
#  (15, 6954),
#  (16, 7764),
#  (17, 4568),
#  (18, 1317),
#  (19, 14386),
#  (20, 3975),
#  (21, 3640),
#  (22, 7351),
#  (23, 8620),
#  (24, 9429),
#  (25, 10933),
#  (26, 2622),
#  (27, 5337),
#  (28, 7975),
#  (29, 5146),
#  (30, 14793),
#  (31, 7257),
#  (32, 871),
#  (33, 1378),
#  (34, 1458),
#  (35, 4670),
#  (36, 140),
#  (37, 531),
#  (38, 2809),
#  (39, 4287),
#  (40, 2648),
#  (41, 1930),
#  (42, 4206),
#  (43, 4543),
#  (44, 5042),
#  (45, 1522),
#  (46, 4043),
#  (47, 549),
#  (48, 1568),
#  (49, 7020),
#  (50, 1620),
#  (51, 1859),
#  (52, 5305),
#  (53, 3240),
#  (54, 1547),
#  (55, 963),
#  (56, 4552),
#  (57, 4823),
#  (58, 9647),
#  (59, 1552),
#  (60, 3167),
#  (61, 7922),
#  (62, 3700),
#  (63, 9915),
#  (64, 2085),
#  (65, 4207),
#  (66, 7086),
#  (67, 5946),
#  (68, 6832),
#  (69, 4051),
#  (70, 6483),
#  (71, 4175),
#  (72, 1636),
#  (73, 4006),
#  (74, 2091),
#  (75, 3271),
#  (76, 786),
#  (77, 4600)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Verify the exact name of the Enrollment column in the database
# Use the SUM() function to add up the Enrollments for each Community Area
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget to group by the Community Area
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from SCHOOLS \
#    group by Community_Area_Name
#
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %%
# %sql SELECT DISTINCT(COMMUNITY_AREA_NUMBER),SUM(COLLEGE_ENROLLMENT) AS SUM_COLL_ENROLL FROM SCHOOLS\
GROUP BY COMMUNITY_AREA_NUMBER\
ORDER BY SUM(COLLEGE_ENROLLMENT)\
LIMIT 5;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [(36, 140), (37, 531), (47, 549), (76, 786), (32, 871)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Order the previous query and limit the number of rows you fetch
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from SCHOOLS \
#    group by Community_Area_Name \
#    order by TOTAL_ENROLLMENT asc \
#    fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 10
#
# ##### List 5 schools with lowest safety score.

# %%
# %sql SELECT NAME_OF_SCHOOL,SAFETY_SCORE FROM SCHOOLS\
ORDER BY SAFETY_SCORE NULLS LAST\
LIMIT 5;
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT name_of_school, safety_score
# FROM schools
# ORDER BY safety_score
# LIMIT 5
# -->

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area which has College Enrollment of 4368

# %%
# Out:
#  * ibm_db_sa://vdx86203:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/bludb
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "HARDSHIP_INDEX" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206
# [SQL: SELECT COLLEGE_ENROLLMENT,HARDSHIP_INDEX FROM SCHOOLS WHERE COLLEGE_ENROLLMENT = 4038;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %%sql
# select hardship_index
#    from chicago_socioeconomic_data CD, schools CPS
#    where CD.ca = CPS.community_area_number
#       and college_enrollment = 4368
#
# -->

# %% [markdown]
# ### Problem 12
#
# ##### Get the hardship index for the community area which has the school with the  highest enrollment.

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
#    where ca in \
#    ( select community_area_number from schools order by college_enrollment desc limit 1 )
#
# -->

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to work with a real word dataset using SQL and Python. You learned how to query columns with spaces or special characters in their names and with mixed case names. You also used built in database functions and practiced how to sort, limit, and order result sets, as well as used sub-queries and worked with multiple tables.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Rav Ahuja</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                        |
# | ----------------- | ------- | ----------------- | ----------------------------------------- |
# | 2021-07-09        | 2.4     | Malika            | Updated connection string                 |
# | 2021-05-19        | 2.3     | Lakshmi Holla     | Updated question                          |
# | 2021-04-20        | 2.2     | Malika            | Added the libraries                       |
# | 2020-11-27        | 2.1     | Sannareddy Ramesh | Modified data sets and added new problems |
# | 2020-08-28        | 2.0     | Lavanya           | Moved lab to course repo in GitLab        |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
